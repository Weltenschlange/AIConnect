# %%
import pandas as pd
from preProccesPuzzle import PreProcess
from clue_classifier import ClueClassifier
from constraints import Constraint, IdentityConstrain, NextToConstrain, DistanceConstrain,RightConstrain, LeftConstrain, DirectRightConstrain, DirectLeftConstrain, PositionAbsoluteConstrain, PositionAbsoluteNegativeConstrain
from constraint_solver import ConstraintSolver
from concurrent.futures import ProcessPoolExecutor
import time

# %%
def constraint_factory(attrs, clues):
    constrains: list[Constraint] = []
    classifier = ClueClassifier()
    for c in clues:
        clue, clue_type = classifier.classify(c)

        if clue_type == "IDENTITY":
            constrains.append(IdentityConstrain(attrs, clue))
        if clue_type == "NEXT_TO":
            constrains.append(NextToConstrain(attrs, clue))
        if clue_type == "LEFT":
            constrains.append(LeftConstrain(attrs, clue))
        if clue_type == "RIGHT":
            constrains.append(RightConstrain(attrs, clue))
        if clue_type == "DISTANCE":
            constrains.append(DistanceConstrain(attrs, clue))
        if clue_type == "DIRECT_LEFT":
            constrains.append(DirectLeftConstrain(attrs, clue))
        if clue_type == "DIRECT_RIGHT":
            constrains.append(DirectRightConstrain(attrs, clue))
        if clue_type == "POSITION_ABSOLUTE":
            constrains.append(PositionAbsoluteConstrain(attrs, clue))
        if clue_type == "POSITION_ABSOLUTE_NEGATIVE":
            constrains.append(PositionAbsoluteNegativeConstrain(attrs, clue))
        if clue_type == "UNKNOWN":
            raise TypeError

    return constrains

# %%
def convert_solver_solution_to_gridmode_format(solver_solution, attrs, gridmode_solution):
    header = gridmode_solution.get("header", [])
    rows = gridmode_solution.get("rows", [])

    # Create mapping by matching header (excluding 'House') with attrs keys in order
    attr_keys = list(attrs.keys())
    header_without_house = [h for h in header if h.lower() != 'house']

    attr_mapping = dict(zip(attr_keys, header_without_house))

    # Convert solver solution to gridmode format
    converted_rows = []
    sorted_positions = sorted(solver_solution.keys())

    for pos in sorted_positions:
        row = []
        attrs_for_pos = solver_solution[pos]

        for header_name in header:
            if header_name.lower() == "house":
                row.append(str(pos))
            else:
                # Find the attr_key for this header column
                attr_key = next((k for k, v in attr_mapping.items() if v == header_name), None)
                if attr_key:
                    value = attrs_for_pos.get(attr_key, "")
                    row.append(str(value))
                else:
                    row.append("")

        converted_rows.append(row)

    converted_solution = {
        "header": list(header),
        "rows": converted_rows
    }

    # Compare with ground truth
    is_correct = True
    mismatches = []

    if len(converted_rows) != len(rows):
        is_correct = False
        mismatches.append(f"Row count mismatch: expected {len(rows)}, got {len(converted_rows)}")

    for i, (converted_row, truth_row) in enumerate(zip(converted_rows, rows)):
        for j, (converted_val, truth_val) in enumerate(zip(converted_row, truth_row)):
            if converted_val.lower() != truth_val.lower():
                is_correct = False
                mismatches.append(
                    f"Row {i}, Column {header[j]}: expected '{truth_val}', got '{converted_val}'"
                )

    return converted_solution, is_correct, mismatches


def validate_solution(solver_solution, attrs, gridmode_solution):

    if not solver_solution:
        print("no solution found!")
        return
    converted_solution, is_correct, mismatches = convert_solver_solution_to_gridmode_format(
        solver_solution, attrs, gridmode_solution
    )
    return is_correct

# %%
gridmode = pd.read_parquet("Gridmode-00000-of-00001.parquet")
mc = pd.read_parquet("mc-00000-of-00001.parquet")
test = pd.read_parquet("Test_100_Puzzles.parquet")

skip = 0

gridmode = gridmode[skip:]

# %%
mc.head(10)
# Out:
#                       id                                             puzzle  \
# 0  lgp-test-6x4-37#mc-16  There are 6 houses, numbered 1 to 6 from left ...
# 1  lgp-test-3x6-15#mc-13  There are 3 houses, numbered 1 to 3 from left ...
# 2   lgp-test-4x6-24#mc-9  There are 4 houses, numbered 1 to 4 from left ...
# 3   lgp-test-5x5-18#mc-0  There are 5 houses, numbered 1 to 5 from left ...
# 4   lgp-test-4x2-35#mc-0  There are 4 houses, numbered 1 to 4 from left ...
# 5   lgp-test-5x2-24#mc-1  There are 5 houses, numbered 1 to 5 from left ...
# 6  lgp-test-4x5-23#mc-19  There are 4 houses, numbered 1 to 4 from left ...
# 7   lgp-test-5x3-34#mc-5  There are 5 houses, numbered 1 to 5 from left ...
# 8    lgp-test-4x3-2#mc-3  There are 4 houses, numbered 1 to 4 from left ...
# 9   lgp-test-5x2-38#mc-5  There are 5 houses, numbered 1 to 5 from left ...
#
#                                             question  \
# 0   What is Name of the person who lives in House 5?
# 1  What is Education of the person who lives in H...
# 2  What is BookGenre of the person who lives in H...
# 3   What is Name of the person who lives in House 1?
# 4   What is Name of the person who lives in House 1?
# 5  What is Smoothie of the person who lives in Ho...
# 6    What is Pet of the person who lives in House 4?
# 7  What is Color of the person who lives in House 2?
# 8   What is Name of the person who lives in House 2?
# 9  What is PhoneModel of the person who lives in ...
#
#                                              choices     answer  \
# 0           [Eric, Bob, Alice, Peter, Carol, Arnold]        Bob
# 1                 [associate, high school, bachelor]  associate
# 2       [science fiction, mystery, romance, fantasy]    mystery
# 3                  [Peter, Bob, Arnold, Eric, Alice]       Eric
# 4                       [Eric, Arnold, Alice, Peter]      Peter
# 5    [lime, cherry, desert, dragonfruit, watermelon]     cherry
# 6                             [fish, cat, bird, dog]       bird
# 7                  [blue, yellow, white, red, green]        red
# 8                       [Alice, Peter, Eric, Arnold]      Alice
# 9  [google pixel 6, huawei p50, samsung galaxy s2...  iphone 13
#
#                    created_at
# 0  2024-07-03T21:21:31.375234
# 1  2024-07-03T21:21:31.316147
# 2  2024-07-03T21:21:31.335059
# 3  2024-07-03T21:21:31.350746
# 4  2024-07-03T21:21:31.319814
# 5  2024-07-03T21:21:31.338848
# 6  2024-07-03T21:21:31.328595
# 7  2024-07-03T21:21:31.342655
# 8  2024-07-03T21:21:31.320129
# 9  2024-07-03T21:21:31.339658

# %%
def solve_puzzle(index,df, verbose=False):
    import json
    import time
    ppp = PreProcess()
    id = df.id.iloc[index]
    puzzle = df.puzzle.iloc[index]
    attrs, clues = ppp.proccess(puzzle)

    # Debug: Check if attrs is empty
    if not attrs:
        print(f"Puzzle {index}: attrs is empty")
        print(f"ID: {id}")
        print(f"Puzzle: {puzzle}")
        return None

    # Convert all attribute keys and values to lowercase
    attrs_lower = {
        k.lower(): [val.lower() if isinstance(val, str) else val for val in v] if isinstance(v, list) else v.lower() if isinstance(v, str) else v
        for k, v in attrs.items()
    }

    # Convert all clues to lowercase
    clues_lower = [clue.lower() if isinstance(clue, str) else clue for clue in clues]

    # Track constraint creation time

    constraint_start = time.time()
    constrains: list[Constraint] = constraint_factory(attrs_lower, clues_lower)
    constraint_time = time.time() - constraint_start

    # Track solver time and save logging
    solver_start = time.time()
    Cs = ConstraintSolver(attrs_lower, constrains)
    solution = Cs.solve()
    solver_time = time.time() - solver_start
    
    try:
        # Use the puzzle ID for the filename
        trace_filename = f"trace_{id}.csv"
        # Call the saving method we added to the solver
        Cs.save_trace_to_csv(trace_filename)
        if verbose:
            print(f"Trace saved to: {trace_filename}")
    except Exception as e:
        print(f"Error saving trace for {id}: {e}")

    if verbose:
        print(puzzle)
        print("================================")
        print("Build constraints")
        for c in constrains:
            print(c.get_info())
        print("================================")
        print("Timing Information")
        print(f"Constraint creation time: {constraint_time:.4f}s")
        print(f"Solver time: {solver_time:.4f}s")
        print(f"Backtrack count: {Cs.backtrack_count}")
        print(f"Propagation calls: {Cs.propagation_calls}")
        print("================================")
        print("Our Solution")
        Cs.print_solution(solution)

    if solution:
        # Create mapping from lowercase to original keys and values
        key_mapping = {k.lower(): k for k in attrs.keys()}
        value_mappings = {}
        for k, v in attrs.items():
            if isinstance(v, list):
                value_mappings[k.lower()] = {val.lower(): val for val in v if isinstance(val, str)}

        # Convert to gridmode format with original attribute casing
        header = ["House"] + [key_mapping.get(k, k) for k in attrs_lower.keys()]
        rows = []
        sorted_positions = sorted(solution.keys())

        for pos in sorted_positions:
            row = [str(pos)]
            for attr_key_lower in attrs_lower.keys():
                attr_key_original = key_mapping.get(attr_key_lower, attr_key_lower)
                value = solution[pos].get(attr_key_lower, "")
                # Map value back to original casing if possible
                if attr_key_lower in value_mappings:
                    value = value_mappings[attr_key_lower].get(value, value)
                row.append(str(value))
            rows.append(row)

        grid_solution = {
            "header": header,
            "rows": rows
        }

        # Return in format: id | grid_solution_json | steps
        result = f"{id} | {json.dumps(grid_solution)} | {Cs.backtrack_count}"
        return result
    if not result:
        result = f"{id} | | {Cs.backtrack_count}"
    return None

def solve_all_puzzles(df):
    total = len(df)
    passed = 0
    failed = []
    times = []
    results = []

    start_total = time.time()

    for i in range(total):
        print(f"Solving {i}/{total}...", end="\r")
        test_start = time.time()
        result = solve_puzzle(i,df)
        if result is None:
            failed.append(i)
            print(f"wrong at index: {i}")
        else:
            results.append(result)
            passed += 1
        test_end = time.time()
        times.append(test_end - test_start)

    total_time = time.time() - start_total
    avg_time = sum(times) / len(times) if times else 0

    print(f"\nResults: {passed}/{total} passed")
    if failed:
        print(f"Failed indices: {failed}")
    print(f"Total time: {total_time:.2f}s | Average time per solution: {avg_time:.4f}s")

    # Print results in specified format
    print("\n" + "="*80)
    print("Results (id | grid_solution | steps):")
    print("="*80)
    for res in results:
        print(res)

# %%
# ==========================================
# TEST RUN FOR LOGGING
# ==========================================

# Select the first puzzle to test
test_index = 0

print(f"Starting test run for puzzle at index {test_index}...")

# This calls your UPDATED function
# It will try to solve the puzzle AND create the CSV file
result = solve_puzzle(test_index, gridmode, verbose=True)

print("\n" + "="*30)
if result:
    print("Solver finished.")

    # Get the ID to show you the filename
    puzzle_id = gridmode.id.iloc[test_index]
    expected_filename = f"trace_{puzzle_id}.csv"

    print(f"CHECK YOUR FILES")
    print(f"Look for a file named: '{expected_filename}'")
else:
    print("Solver failed (no solution found).")
# Out:
# Starting test run for puzzle at index 0...
# Trace successfully saved to trace_lgp-test-5x6-16.csv (185 rows)
# Trace saved to: trace_lgp-test-5x6-16.csv
# There are 5 houses, numbered 1 to 5 from left to right, as seen from across the street. Each house is occupied by a different person. Each house has a unique attribute for each of the following characteristics:
#  - Each person has a unique name: `Peter`, `Alice`, `Bob`, `Eric`, `Arnold`
#  - The people are of nationalities: `norwegian`, `german`, `dane`, `brit`, `swede`
#  - People have unique favorite book genres: `fantasy`, `biography`, `romance`, `mystery`, `science fiction`
#  - Everyone has something unique for lunch: `stir fry`, `grilled cheese`, `pizza`, `spaghetti`, `stew`
#  - Each person has a favorite color: `red`, `green`, `blue`, `yellow`, `white`
#  - The people keep unique animals: `bird`, `dog`, `cat`, `horse`, `fish`
#
# ## Clues:
# 1. The person who loves fantasy books is the Norwegian.
# 2. The cat lover and the person who loves biography books are next to each other.
# 3. The German is Bob.
# 4. The person who loves yellow is Bob.
# 5. The person whose favorite color is green is Peter.
# 6. There is one house between the Dane and the person who is a pizza lover.
# 7. The person who loves blue is somewhere to the left of the Dane.
# 8. The person who loves eating grilled cheese is somewhere to the left of the Norwegian.
# 9. The person who loves the spaghetti eater is Peter.
# 10. The person who keeps horses is Alice.
# 11. The fish enthusiast is directly left of the person who loves science fiction books.
# 12. There is one house between the Norwegian and Arnold.
# 13. The person who loves romance books is the British person.
# 14. There are two houses between the Norwegian and Alice.
# 15. The bird keeper is the person whose favorite color is red.
# 16. The dog owner is directly left of the fish enthusiast.
# 17. The person who loves the stew is the Norwegian.
#
# ================================
# Build constraints
# IdentityConstrain:  the person who loves fantasy books is the norwegian.
# attr1:('fantasy', 'book')
# attr2:('norwegian', 'nationalities')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# NextToConstrain: the cat lover and the person who loves biography books are next to each other.
# attr1:('cat', 'animals')
# attr2:('biography', 'book')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the german is bob.
# attr1:('german', 'nationalities')
# attr2:('bob', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person who loves yellow is bob.
# attr1:('yellow', 'color')
# attr2:('bob', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person whose favorite color is green is peter.
# attr1:('green', 'color')
# attr2:('peter', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# DistanceConstrain: there is one house between the dane and the person who is a pizza lover.
# distance:1
# attr1:('dane', 'nationalities')
# attr2:('pizza', 'lunch')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# LeftConstrain: the person who loves blue is somewhere to the left of the dane.
# attr1:('blue', 'color')
# attr2:('dane', 'nationalities')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# LeftConstrain: the person who loves eating grilled cheese is somewhere to the left of the norwegian.
# attr1:('grilled cheese', 'lunch')
# attr2:('norwegian', 'nationalities')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person who loves the spaghetti eater is peter.
# attr1:('spaghetti', 'lunch')
# attr2:('peter', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person who keeps horses is alice.
# attr1:('horse', 'animals')
# attr2:('alice', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# DirectLeftConstrain: the fish enthusiast is directly left of the person who loves science fiction books.
# attr1:('fish', 'animals')
# attr2:('science fiction', 'book')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# DistanceConstrain: there is one house between the norwegian and arnold.
# distance:1
# attr1:('norwegian', 'nationalities')
# attr2:('arnold', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person who loves romance books is the british person.
# attr1:('romance', 'book')
# attr2:('brit', 'nationalities')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# DistanceConstrain: there are two houses between the norwegian and alice.
# distance:2
# attr1:('norwegian', 'nationalities')
# attr2:('alice', 'name')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the bird keeper is the person whose favorite color is red.
# attr1:('bird', 'animals')
# attr2:('red', 'color')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# DirectLeftConstrain: the dog owner is directly left of the fish enthusiast.
# attr1:('dog', 'animals')
# attr2:('fish', 'animals')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# IdentityConstrain:  the person who loves the stew is the norwegian.
# attr1:('stew', 'lunch')
# attr2:('norwegian', 'nationalities')
# attributes:{'name': ['peter', 'alice', 'bob', 'eric', 'arnold'], 'nationalities': ['norwegian', 'german', 'dane', 'brit', 'swede'], 'book': ['fantasy', 'biography', 'romance', 'mystery', 'science fiction'], 'lunch': ['stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew'], 'color': ['red', 'green', 'blue', 'yellow', 'white'], 'animals': ['bird', 'dog', 'cat', 'horse', 'fish']}
#
# ================================
# Timing Information
# Constraint creation time: 0.0015s
# Solver time: 0.8434s
# Backtrack count: 125
# Propagation calls: 186
# ================================
# Our Solution
#
# === Solution ===
#
# House 1:
#   animals: dog
#   book: mystery
#   color: yellow
#   lunch: grilled cheese
#   name: bob
#   nationalities: german
#
# House 2:
#   animals: fish
#   book: fantasy
#   color: blue
#   lunch: stew
#   name: eric
#   nationalities: norwegian
#
# House 3:
#   animals: cat
#   book: science fiction
#   color: green
#   lunch: spaghetti
#   name: peter
#   nationalities: dane
#
# House 4:
#   animals: bird
#   book: biography
#   color: red
#   lunch: stir fry
#   name: arnold
#   nationalities: swede
#
# House 5:
#   animals: horse
#   book: romance
#   color: white
#   lunch: pizza
#   name: alice
#   nationalities: brit
#
# ==============================
# Solver finished.
# CHECK YOUR FILES
# Look for a file named: 'trace_lgp-test-5x6-16.csv'

# %%
def solve_test(index, verbose=False):
    ppp = PreProcess()

    provided_solution = gridmode.solution.iloc[index]
    puzzle = gridmode.puzzle.iloc[index].lower()
    attrs, clues = ppp.proccess(puzzle)


    unsolvable = 0
    for key in attrs.keys():
        if key == "pet" or key == "animals":
            unsolvable += 1
            if unsolvable == 2:
                # Check if pet and animals have overlapping values
                pet_values = set(attrs.get("pet", []))
                animals_values = set(attrs.get("animals", []))
                overlap = pet_values & animals_values  # intersection
                if overlap:
                    if verbose:
                        print(puzzle)
                        print("================================")
                    print(f"Puzzle {index} not solvable because pet and animals have overlapping values: {overlap}")
                    print(f"can not deside what value belongs to what attribute")
                    return False

    # Track constraint creation time
    constraint_start = time.time()
    constrains: list[Constraint] = constraint_factory(attrs, clues)
    constraint_time = time.time() - constraint_start

    # Track solver time
    solver_start = time.time()
    Cs = ConstraintSolver(attrs, constrains)
    solution = Cs.solve()
    solver_time = time.time() - solver_start

    if verbose:
        print(puzzle)
        print("================================")
        print("Provided solution")
        print(provided_solution)
        print("================================")
        print("Build constraints")
        for c in constrains:
            print(c.get_info())
        print("================================")
        print("Timing Information")
        print(f"Constraint creation time: {constraint_time:.4f}s")
        print(f"Solver time: {solver_time:.4f}s")
        print(f"Backtrack count: {Cs.backtrack_count}")
        print(f"Propagation calls: {Cs.propagation_calls}")
        print("================================")
        print("Our Solution")
        Cs.print_solution(solution)

    return validate_solution(solution, attrs, provided_solution)

def solve_all_tests():
    total = len(gridmode)
    passed = 0
    failed = []
    times = []

    start_total = time.time()

    for i in range(total):
        print(f"Testing {i}/{total}...", end="\r")
        test_start = time.time()
        if not solve_test(i):
            failed.append(i)
            print(f"wrong at index: {i} true index: {i+skip}")
        test_end = time.time()
        times.append(test_end - test_start)
        passed += 1

    total_time = time.time() - start_total
    avg_time = sum(times) / len(times) if times else 0

    print(f"\nResults: {passed}/{total} passed")
    if failed:
        print(f"Failed indices: {failed}")
    print(f"Total time: {total_time:.2f}s | Average time per solution: {avg_time:.4f}s")

# %%
solve_test(4,verbose=True)
# Out:
# there are 2 houses, numbered 1 to 2 from left to right, as seen from across the street. each house is occupied by a different person. each house has a unique attribute for each of the following characteristics:
#  - each person has a unique name: `eric`, `arnold`
#  - each person has a unique type of pet: `dog`, `cat`
#
# ## clues:
# 1. eric is somewhere to the left of arnold.
# 2. the person who owns a dog is not in the first house.
#
# ================================
# Provided solution
# {'header': array(['House', 'Name', 'Pet'], dtype=object), 'rows': array([array(['1', 'Eric', 'cat'], dtype=object),
#        array(['2', 'Arnold', 'dog'], dtype=object)], dtype=object)}
# ================================
# Build constraints
# LeftConstrain: eric is somewhere to the left of arnold.
# attr1:('eric', 'name')
# attr2:('arnold', 'name')
# attributes:{'name': ['eric', 'arnold'], 'pet': ['dog', 'cat']}
#
# PositionAbsoluteNegativeConstrain: the person who owns a dog is not in the first house.
# Position:1
# attr1:('dog', 'pet')
# attributes:{'name': ['eric', 'arnold'], 'pet': ['dog', 'cat']}
#
# ================================
# Timing Information
# Constraint creation time: 0.0001s
# Solver time: 0.0012s
# Backtrack count: 4
# Propagation calls: 6
# ================================
# Our Solution
#
# === Solution ===
#
# House 1:
#   name: eric
#   pet: cat
#
# House 2:
#   name: arnold
#   pet: dog
# True

# %%
#solve_all_tests()
# Out:
# Puzzle 211 not solvable because pet and animals have overlapping values: {'bird', 'cat', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 211 true index: 211
# Puzzle 225 not solvable because pet and animals have overlapping values: {'cat'}
# can not deside what value belongs to what attribute
# wrong at index: 225 true index: 225
# Puzzle 337 not solvable because pet and animals have overlapping values: {'bird', 'cat', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 337 true index: 337
# Puzzle 388 not solvable because pet and animals have overlapping values: {'cat'}
# can not deside what value belongs to what attribute
# wrong at index: 388 true index: 388
# Puzzle 396 not solvable because pet and animals have overlapping values: {'cat'}
# can not deside what value belongs to what attribute
# wrong at index: 396 true index: 396
# Puzzle 406 not solvable because pet and animals have overlapping values: {'cat'}
# can not deside what value belongs to what attribute
# wrong at index: 406 true index: 406
# Puzzle 419 not solvable because pet and animals have overlapping values: {'fish', 'cat', 'bird', 'dog'}
# can not deside what value belongs to what attribute
# wrong at index: 419 true index: 419
# Puzzle 427 not solvable because pet and animals have overlapping values: {'dog', 'cat', 'bird', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 427 true index: 427
# Puzzle 522 not solvable because pet and animals have overlapping values: {'bird', 'cat', 'fish', 'dog', 'rabbit'}
# can not deside what value belongs to what attribute
# wrong at index: 522 true index: 522
# Puzzle 614 not solvable because pet and animals have overlapping values: {'bird', 'cat', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 614 true index: 614
# Puzzle 848 not solvable because pet and animals have overlapping values: {'dog', 'cat', 'bird', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 848 true index: 848
# Puzzle 852 not solvable because pet and animals have overlapping values: {'dog', 'cat', 'bird', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 852 true index: 852
# Puzzle 922 not solvable because pet and animals have overlapping values: {'dog', 'cat', 'bird', 'fish'}
# can not deside what value belongs to what attribute
# wrong at index: 922 true index: 922
# Testing 999/1000...
# Results: 1000/1000 passed
# Failed indices: [211, 225, 337, 388, 396, 406, 419, 427, 522, 614, 848, 852, 922]
# Total time: 292.68s | Average time per solution: 0.2926s

# %%
#print(solve_puzzle(922,gridmode,verbose=True))

solve_all_puzzles(gridmode)
# Out:
# Trace successfully saved to trace_lgp-test-5x6-16.csv (185 rows)
# Trace successfully saved to trace_lgp-test-4x4-27.csv (18 rows)
# Trace successfully saved to trace_lgp-test-6x4-15.csv (83 rows)
# Trace successfully saved to trace_lgp-test-6x5-2.csv (57 rows)
# Trace successfully saved to trace_lgp-test-2x2-33.csv (5 rows)
# Trace successfully saved to trace_lgp-test-4x4-3.csv (32 rows)
# Trace successfully saved to trace_lgp-test-2x4-5.csv (8 rows)
# Trace successfully saved to trace_lgp-test-5x5-30.csv (28 rows)
# Trace successfully saved to trace_lgp-test-3x5-34.csv (17 rows)
# Trace successfully saved to trace_lgp-test-4x5-3.csv (21 rows)
# Trace successfully saved to trace_lgp-test-2x6-24.csv (12 rows)
# Trace successfully saved to trace_lgp-test-6x2-9.csv (20 rows)
# Trace successfully saved to trace_lgp-test-4x2-18.csv (13 rows)
# Trace successfully saved to trace_lgp-test-5x2-15.csv (10 rows)
# Trace successfully saved to trace_lgp-test-5x4-2.csv (54 rows)
# Trace successfully saved to trace_lgp-test-4x4-21.csv (22 rows)
# Trace successfully saved to trace_lgp-test-5x6-0.csv (38 rows)
# Trace successfully saved to trace_lgp-test-2x3-9.csv (7 rows)
# Trace successfully saved to trace_lgp-test-5x5-12.csv (43 rows)
# Trace successfully saved to trace_lgp-test-3x5-16.csv (16 rows)
# Trace successfully saved to trace_lgp-test-4x3-10.csv (15 rows)
# Trace successfully saved to trace_lgp-test-5x6-30.csv (46 rows)
# Trace successfully saved to trace_lgp-test-3x5-30.csv (21 rows)
# Trace successfully saved to trace_lgp-test-4x3-27.csv (21 rows)
# Trace successfully saved to trace_lgp-test-5x2-22.csv (10 rows)
# Trace successfully saved to trace_lgp-test-4x3-36.csv (21 rows)
# Trace successfully saved to trace_lgp-test-5x2-14.csv (10 rows)
# Trace successfully saved to trace_lgp-test-4x5-34.csv (40 rows)
# Trace successfully saved to trace_lgp-test-3x6-5.csv (39 rows)
# Trace successfully saved to trace_lgp-test-5x6-10.csv (252 rows)
# Trace successfully saved to trace_lgp-test-5x2-30.csv (11 rows)
# Solving 31/1000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 #print(solve_puzzle(922,gridmode,verbose=True))
# ----> 3 solve_all_puzzles(gridmode)
#
# Cell In[19], line 111, in solve_all_puzzles(df)
#     109 print(f"Solving {i}/{total}...", end="\r")
#     110 test_start = time.time()
# --> 111 result = solve_puzzle(i,df)
#     112 if result is None:
#     113     failed.append(i)
#
# Cell In[19], line 36, in solve_puzzle(index, df, verbose)
#      32 solver_start = time.time()
#      33 Cs = ConstraintSolver(attrs_lower, constrains)
# ---> 36 solution = Cs.solve()
#      37 solver_time = time.time() - solver_start
#      38 try:
#      39     # Use the puzzle ID for the filename
#
# File d:\Studium\3Semester\AIConnect\AIConnect\constraint_solver.py:44, in ConstraintSolver.solve(self)
#      41 if not self._ac3():
#      42     return None
# ---> 44 if not self._propagate():
#      45     return None
#      47 return self._backtrack({})
#
# File d:\Studium\3Semester\AIConnect\AIConnect\constraint_solver.py:100, in ConstraintSolver._propagate(self)
#      97     test_solution = self._build_partial_solution()
#      98     test_solution[houseNr][attr_key] = value
# --> 100     if not self._is_consistent(test_solution):
#     101         values_to_remove.add(value)
#     103 if values_to_remove:
#
# File d:\Studium\3Semester\AIConnect\AIConnect\constraint_solver.py:294, in ConstraintSolver._is_consistent(self, assignment)
#     291             used_values.append(value)
#     293 for constraint in self.constraints:
# --> 294     if not constraint.is_valid(assignment):
#     295         return False
#     297 return True
#
# File d:\Studium\3Semester\AIConnect\AIConnect\constraints.py:133, in IdentityConstrain.is_valid(self, currentSolution)
#     130 attr2_val, attr2_key = self.attr2
#     132 pos1 = self._get_position_by_attribute(attr1_val, attr1_key, currentSolution)
# --> 133 pos2 = self._get_position_by_attribute(attr2_val, attr2_key, currentSolution)
#     135 # If one is assigned and the other is not, it's still potentially valid
#     137 if pos1 is None or pos2 is None:
#
# File d:\Studium\3Semester\AIConnect\AIConnect\constraints.py:116, in Constraint._get_position_by_attribute(self, attr_value, attr_key, currentSolution)
#     114 def _get_position_by_attribute(self, attr_value, attr_key, currentSolution):
#     115     for pos, attrs in currentSolution.items():
# --> 116         if attrs.get(attr_key) == attr_value:
#     117             return pos
#     118     return None
#
# KeyboardInterrupt:
